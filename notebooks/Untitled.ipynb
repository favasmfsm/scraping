# %%
import pandas as pd

# %%
df = pd.read_csv("final_data_with_form_name.csv")
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_3950/1125918065.py:1: DtypeWarning: Columns (8,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("final_data_with_form_name.csv")

# %%
df.sample(2)
# Out:
#                                               Company Name  NAIC Company Code  \
# 3418278  Health Care Service Corporation, a Mutual Lega...            70670.0
# 4703640                   Principal Life Insurance Company            61271.0
#
#         Insurance Product Name  \
# 3418278  BCBSNM Individual PPO
# 4703640             Dental PPO
#
#                                    Sub Type Of Insurance  \
# 3418278  H16I.005A Individual - Preferred Provider (PPO)
# 4703640                                 Dental (H10.000)
#
#                    Filing Type                Filing Status  \
# 3418278              Form/Rate  Closed - Approved Certified
# 4703640  Other - Informational               Closed - Filed
#
#                  SERFF Tracking Number  Page Number      serf_num state  \
# 3418278                 NWMC-129449983           70     129449983    NM
# 4703640  USPH-6L5QJC333/00-00/00-00/00          171  6L5QJC333/00    IL
#
# ...

# %%
df[(df.readability_score.notna()) & (df.form_name.apply(lambda x: "read" not in (str(x).lower())))]
# Out:
#                                    Company Name  NAIC Company Code  \
# 19                   AAA Life Insurance Company            71854.0
# 23                   AAA Life Insurance Company            71854.0
# 38                   AAA Life Insurance Company            71854.0
# 73                   AAA Life Insurance Company            71854.0
# 147                  AAA Life Insurance Company            71854.0
# ...                                         ...                ...
# 4883689  Zurich American Life Insurance Company            90557.0
# 4883690  Zurich American Life Insurance Company            90557.0
# 4883691  Zurich American Life Insurance Company            90557.0
# 4883692  Zurich American Life Insurance Company            90557.0
# 4883693  Zurich American Life Insurance Company            90557.0
#
#                  Insurance Product Name  \
# 19       Member Loyalty Travel Accident
# 23       Member Loyalty Travel Accident
# ...

# %%
df.

# %%
df[['SERFF Tracking Number', 'state', 'file_name', 'attachment_type', 'number_of_pages',
       'readability_score', 'form_name']]
# Out:
#         SERFF Tracking Number state  \
# 0              AAAL-125053950    RI
# 1              AAAL-125053950    RI
# 2              AAAL-125053950    RI
# 3              AAAL-125053950    RI
# 4              AAAL-125053950    RI
# ...                       ...   ...
# 4883710        ZUUG-132507564    MO
# 4883711        ZUUG-132507564    MO
# 4883712        ZUUG-132507564    MO
# 4883713        ZUUG-134054739    MI
# 4883714        ZUUG-134491160    MI
#
#                                                  file_name  \
# 0                                      Trust Agreement.pdf
# 1                                Group Ins[1].Ck.list1.pdf
# 2                                   Statement of Rates.pdf
# 3                              Actuarial Certification.pdf
# 4        Amended and Restated Trust for the AAA Group I...
# ...                                                    ...
# 4883710  Ferrellgas ADL and Limited Benefits Endorsemen...
# ...

# %%
old_data = pd.read_csv("data_with_flesh_score_complete_set.csv")
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_3950/3325111460.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   old_data = pd.read_csv("data_with_flesh_score_complete_set.csv")

# %%
old_data.shape
# Out:
# (2286347, 17)

# %%
old_data.sample(3)
# Out:
#                                               Company Name  NAIC Company Code  \
# 853852                      ACE American Insurance Company            22667.0
# 2164216                  Zurich American Insurance Company            16535.0
# 1984589  American Family Life Assurance Company of Colu...            60380.0
#
#                    Insurance Product Name  \
# 853852    Group Hospital Indemnity Policy
# 2164216  Zurich Accident for Groups (ZAG)
# 1984589            AFLAC Group Dental PPO
#
#                         Sub Type Of Insurance Filing Type      Filing Status  \
# 853852   H14G.000 Health - Hospital Indemnity        Form  Closed - Approved
# 2164216       H02G.000 Health - Accident Only   Form/Rate  Closed - Approved
# 1984589              H10G.000 Health - Dental   Form/Rate  Closed - Approved
#
#         SERFF Tracking Number  Page Number   serf_num state  \
# 853852         ACEH-129921659            1  129921659    CT
# ...

# %%
old_data.shape
# Out:
# (2286347, 17)

# %%
old_data.columns
# Out:
# Index(['Company Name', 'NAIC Company Code', 'Insurance Product Name',
#        'Sub Type Of Insurance', 'Filing Type', 'Filing Status',
#        'SERFF Tracking Number', 'Page Number', 'serf_num', 'state', 'page_url',
#        'form', 'auth_url', 'form_name', 'submission_date',
#        'flesch_reading_ease', 'serf_int'],
#       dtype='object')

# %%
export_df = old_data[['SERFF Tracking Number', 'serf_num', 'state', 'page_url','form', 'auth_url',]]
export_df.drop_duplicates(inplace=True)
export_df.to_csv("old_data_from_name_fetch.csv",index=False)
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_3950/3839639682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export_df.drop_duplicates(inplace=True)

# %%
outputs = "../outputs/"

processed_files = [
    os.path.join(outputs, f)
    for f in os.listdir(outputs)
    if f.endswith(".csv")
]

# %%
import os
import pandas as pd

folder = "new_outputs/read_page/outputs"

csv_files = [
    os.path.join(folder, f)
    for f in os.listdir(folder)
    if f.endswith(".csv")
]

csv_files+=processed_files

already_completed = pd.concat(
    [pd.read_csv(f) for f in csv_files],
    ignore_index=True
)

# %%
already_completed.dropna(subset="form_name_mapping",inplace=True)

# %%
already_completed.shape
# Out:
# (102969, 15)

# %%
export_df2 = export_df[~export_df['SERFF Tracking Number'].isin(already_completed["SERFF Tracking Number"])]
export_df2 = export_df2[export_df2['SERFF Tracking Number'].isin(df[df.readability_score.notna()]["SERFF Tracking Number"])]

export_df2.to_csv("../data/old_data_from_name_fetch_3.csv",index=False)

# %%
export_df2.shape
# Out:
# (59271, 6)

# %%
export_df2[export_df2['serf_num']=="6UAHR6436/00"].values
# Out:
# array([['USPH-6UAHR6436/00-00/00-00/00', '6UAHR6436/00', 'SD',
#         'https://filingaccess.serff.com/sfa/search/filingSummary.xhtml?filingId=6UAHR6436/00',
#         True, 'https://filingaccess.serff.com/sfa/home/SD']], dtype=object)

# %%
old_data.drop_duplicates(subset=['SERFF Tracking Number','form_name'])
# Out:
#                               Company Name  NAIC Company Code  \
# 0        John Alden Life Insurance Company            65080.0
# 1         Union Security Insurance Company            70408.0
# 2        John Alden Life Insurance Company            65080.0
# 3                StarNet Insurance Company            40045.0
# 4        John Alden Life Insurance Company            65080.0
# ...                                    ...                ...
# 2286342  Fortis Benefits Insurance Company            70408.0
# 2286343  John Alden Life Insurance Company            65080.0
# 2286344  John Alden Life Insurance Company            65080.0
# 2286345             Time Insurance Company            69477.0
# 2286346    New York Life Insurance Company            66915.0
#
#                                     Insurance Product Name  \
# 0                                  John Alden-Base Chassis
# 1              USIC-2500P Union Security Disability Income
# ...

# %%
result_1 = pd.merge(old_data[old_data.form_name.notna()],df[['SERFF Tracking Number', 'file_name', 'attachment_type', 'number_of_pages',
       'readability_score', 'form_name']],on=['SERFF Tracking Number','form_name'])

# %%
result_1[result_1.readability_score.notna()].to_csv("file_mapped_with_readability_score.csv",index=False)

# %%
result_1[result_1.readability_score.notna()].shape
# Out:
# (72233, 21)

# %%
result_1.shape
# Out:
# (593309, 21)

# %%
result_1[result_1.readability_score.notna()]
# Out:
#                                              Company Name  NAIC Company Code  \
# 16                      Bankers Life and Casualty Company            61263.0
# 17                      Bankers Life and Casualty Company            61263.0
# 18                      Bankers Life and Casualty Company            61263.0
# 19                      Bankers Life and Casualty Company            61263.0
# 20                      Bankers Life and Casualty Company            61263.0
# ...                                                   ...                ...
# 592976                          Oakwood Insurance Company            31208.0
# 592977                          Oakwood Insurance Company            31208.0
# 593301  National Union Fire Insurance Company of Pitts...            19445.0
# 593302  National Union Fire Insurance Company of Pitts...            19445.0
# 593303  National Union Fire Insurance Company of Pitts...            19445.0
#
# ...
